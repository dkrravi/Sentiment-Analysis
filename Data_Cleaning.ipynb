# %%
import pandas as pd
import re
from textblob import TextBlob

# %%
df = pd.read_csv("Comments.csv")

# %%
df.head()
# Out:
#                                              comment
# 0  Alex, please always number the videos of your ...
# 1  Hi Sir I'm feared to take data analytics just ...
# 2  Hi Alex, I’ve been watching your videos and it...
# 3  I wonder why I didn't get a heads-up for the l...
# 4  ⌚Timestamps: 0:02 - Introduction to the live s...

# %%
df = df[['comment']]

# %%
df.head()
# Out:
#                                              comment
# 0  Alex, please always number the videos of your ...
# 1  Hi Sir I'm feared to take data analytics just ...
# 2  Hi Alex, I’ve been watching your videos and it...
# 3  I wonder why I didn't get a heads-up for the l...
# 4  ⌚Timestamps: 0:02 - Introduction to the live s...

# %%
def clean_text(text):
    text = str(text)
    text = re.sub(r"http\S+|www\S+|https\S+", '', text)
    text = re.sub(r"[^a-zA-Z\s]", '', text)
    text = re.sub(r"\s+", ' ', text)
    return text.lower().strip()

df['clean_comment'] = df['comment'].apply(clean_text)

# %%
def get_sentiment_label(text):
    polarity = TextBlob(text).sentiment.polarity
    if polarity > 0.1:
        return 1
    elif polarity < -0.1:
        return -1
    else:
        return 0

df['sentiment'] = df['clean_comment'].apply(get_sentiment_label)

# %%
df = df[df['clean_comment'].str.strip() != '']

# %%
df[['clean_comment', 'sentiment']].to_csv("YT comments.csv", index=False)
